# %%
# increase default window size for notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# C:\Users\s.kaiser\AppData\Local\Temp\ipykernel_37080\696421802.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %%
# one time install
# !pip install theano

# %%
import sys, os
cwd = sys.path[0]
sys.path.append(os.path.join(cwd, 'my_modules'))                # sys.path[0] is dir of the ipynb file
import custom_plot
import data_clean
import data_preprocess
import constants
# Out:
# imported custom_plot.py
# data_clean imported
# data_preprocess imported

# %%
# import os;
# import theano
# os.environ['KERAS_BACKEND'] = 'theano'
# !python --version
# theano.test()
# Out:
# Python 3.9.7

# %%
import os
# os.environ["KERAS_BACKEND"] = "theano"
import keras; import keras.backend
print(keras.backend.backend())   # check keras backend
# if keras.backend.backend() != 'theano':
#     raise BaseException("This script uses other backend")
# else:
#     keras.backend.set_image_dim_ordering('th')
#     print("Backend ok")
# Out:
# tensorflow

# %%
import numpy as np
from standard_plots import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
dataset = np.cos(np.arange(1000)*(20*np.pi/1000))[:,None]
# print(dataset)
plt_plot(y = dataset)

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        dataX.append(dataset[i:(i+look_back), 0])
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 20
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# split into train and test sets
train_val_size = int(len(dataset) * 0.8)
test_size = len(dataset) - train_val_size
train_val, test = dataset[0:train_val_size,:], dataset[train_val_size:len(dataset),:]

# validation data, first 80% of train_val is train, rest is validation data
train_size = int(len(train_val) * 0.8)
val_size = len(train_val) - train_size
train, val = dataset[0:train_size,:], train_val[train_size:len(train_val),:]

trainX, trainY = create_dataset(train, look_back)
val_X, val_y = create_dataset(val, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
val_X = np.reshape(val_X, (val_X.shape[0], val_X.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

print(len(dataset), train_val_size, test_size, train_size, val_size)
# Out:
# 1000 800 200 640 160

# %%
# print(trainX)
# print(trainY)
print(train.shape)
print(trainX.shape)
print(val_X.shape)
print(testX.shape)
# Out:
# (640, 1)
# (620, 20, 1)
# (140, 20, 1)
# (180, 20, 1)

# %%
# %%time
dir_path = os.path.join(cwd, 'test_cosine')
model_path = os.path.join(dir_path, 'model.h5')
all_history = pd.DataFrame()

# theano.config.compute_test_value = "ignore"
# create and fit the LSTM network
batch_size = 1
model = Sequential()
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
# model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
# model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))
model.summary()

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=3,verbose=0,mode='min'),  # minimize validation loss
    tf.keras.callbacks.ModelCheckpoint(filepath=model_path, monitor='val_loss', mode='min', save_best_only=True)
]
# loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[MeanSquaredError()]
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[MeanSquaredError()])
for i in range(10):
    history = model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, validation_data=(val_X, val_y), callbacks=my_callbacks, shuffle=False)
    this_history = pd.DataFrame(history.history)
    all_history = pd.concat([all_history, this_history])   
    model.reset_states()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (1, 32)                   4352
#
#  dropout_10 (Dropout)        (1, 32)                   0
#
#  dense_10 (Dense)            (1, 1)                    33
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# 620/620 - 5s - loss: 0.1213 - mean_squared_error: 0.1213 - val_loss: 0.0407 - val_mean_squared_error: 0.0407 - 5s/epoch - 8ms/step
# 620/620 - 3s - loss: 0.0473 - mean_squared_error: 0.0473 - val_loss: 0.0307 - val_mean_squared_error: 0.0307 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0367 - mean_squared_error: 0.0367 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - 3s/epoch - 4ms/step
# 620/620 - 3s - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 3s/epoch - 4ms/step
# 620/620 - 3s - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 7.3390e-04 - val_mean_squared_error: 7.3390e-04 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 6.8222e-04 - val_mean_squared_error: 6.8222e-04 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 9.7571e-04 - val_mean_squared_error: 9.7571e-04 - 3s/epoch - 5ms/step
# 620/620 - 3s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 4.6807e-04 - val_mean_squared_error: 4.6807e-04 - 3s/epoch - 5ms/step
# CPU times: total: 1min 7s
# Wall time: 32.5 s

# %%
# %matplotlib notebook
print(all_history)

# Plot history (train, val loss vs epochs)

v = all_history.values.tolist()
c = all_history.columns.values.tolist()
dict_history = [dict(zip(c, x)) for x in v]

import matplotlib
font = {'family' : 'normal',
    'weight' : 'bold',
    'size'   : 10}

matplotlib.rc('font', **font)
fig = plt.figure(figsize =(12 ,5))
# dict_history = all_history.to_dict('records')
print(dict_history)
# print('train loss: ', dict_history['loss'])
# print('val loss: ', dict_history['val_loss'])
# plt.plot(dict_history['loss'])
# plt.plot(dict_history['val_loss'])
# plt.title('title')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper right')
# plt.show()
# Out:
#        loss  mean_squared_error  val_loss  val_mean_squared_error
# 0  0.121304            0.121304  0.040667                0.040667
# 0  0.047259            0.047259  0.030659                0.030659
# 0  0.036654            0.036654  0.019296                0.019296
# 0  0.026872            0.026872  0.014757                0.014757
# 0  0.017274            0.017274  0.005014                0.005014
# 0  0.009436            0.009436  0.001880                0.001880
# 0  0.008212            0.008212  0.000734                0.000734
# 0  0.008009            0.008009  0.000682                0.000682
# 0  0.007106            0.007106  0.000976                0.000976
# 0  0.006818            0.006818  0.000468                0.000468
# <img src="data:image/png;base64,..." width="864">
# [{'loss': 0.12130361795425415, 'mean_squared_error': 0.12130361795425415, 'val_loss': 0.04066743701696396, 'val_mean_squared_error': 0.04066743701696396}, {'loss': 0.04725901037454605, 'mean_squared_error': 0.04725901037454605, 'val_loss': 0.03065853752195835, 'val_mean_squared_error': 0.03065853752195835}, {'loss': 0.03665412217378616, 'mean_squared_error': 0.03665412217378616, 'val_loss': 0.01929573528468609, 'val_mean_squared_error': 0.01929573528468609}, {'loss': 0.026872266083955765, 'mean_squared_error': 0.026872266083955765, 'val_loss': 0.014756624586880207, 'val_mean_squared_error': 0.014756624586880207}, {'loss': 0.017273951321840286, 'mean_squared_error': 0.017273951321840286, 'val_loss': 0.005013801157474518, 'val_mean_squared_error': 0.005013801157474518}, {'loss': 0.009436279535293579, 'mean_squared_error': 0.009436279535293579, 'val_loss': 0.0018796288641169667, 'val_mean_squared_error': 0.0018796288641169667}, {'loss': 0.008211681619286537, 'mean_squared_error': 0.008211681619286537, 'val_loss': 0.0007338961586356163, 'val_mean_squared_error': 0.0007338961586356163}, {'loss': 0.008009469136595726, 'mean_squared_error': 0.008009469136595726, 'val_loss': 0.0006822182913310826, 'val_mean_squared_error': 0.0006822182913310826}, {'loss': 0.007106214761734009, 'mean_squared_error': 0.007106214761734009, 'val_loss': 0.000975706847384572, 'val_mean_squared_error': 0.000975706847384572}, {'loss': 0.006818478927016258, 'mean_squared_error': 0.006818478927016258, 'val_loss': 0.0004680715501308441, 'val_mean_squared_error': 0.0004680715501308441}]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [75], in <cell line: 17>()
#      14 print(dict_history)
#      15 # print('train loss: ', dict_history['loss'])
#      16 # print('val loss: ', dict_history['val_loss'])
# ---> 17 plt.plot(dict_history['loss'])
#      18 plt.plot(dict_history['val_loss'])
#      19 plt.title('title')
#
# TypeError: list indices must be integers or slices, not str

# %%
trainScore = model.evaluate(trainX, trainY, batch_size=batch_size, verbose=0)
print('Train Score: ', trainScore)
testScore = model.evaluate(testX[:252], testY[:252], batch_size=batch_size, verbose=0)
print('Test Score: ', testScore)
# Out:
# Train Score:  0.0007317326380871236
# Test Score:  0.000740090967155993

# %%
look_ahead = 250
trainPredict = [np.vstack([trainX[-1][1:], trainY[-1]])]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([trainPredict[-1]]), batch_size=batch_size)
    predictions[i] = prediction
    trainPredict.append(np.vstack([trainPredict[-1][1:],prediction]))

# %%
plt.figure(figsize=(12,5))
# plt.plot(np.arange(len(trainX)),np.squeeze(trainX))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(trainPredict)[:,None][1:]))
# plt.plot(np.arange(200),scaler.inverse_transform(np.squeeze(testY)[:,None][:200]),'r')
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),dataset[train_size:(train_size+look_ahead)],label="test function")
plt.legend()
plt.show()

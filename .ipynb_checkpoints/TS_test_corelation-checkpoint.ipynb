# %%
# %reload_ext autoreload
# for auto reloading modules without kernel restart
# If this does not work to import custom modules, then restart kernel

# %%
# increase default window size for notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# C:\Users\s.kaiser\AppData\Local\Temp\ipykernel_13368\696421802.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %%
import os
import warnings

warnings.filterwarnings("ignore")  # avoid printing out absolute paths

os.chdir("../../..")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import timeit
from datetime import timedelta
from dataclasses import dataclass       # C like structure
import glob                             # finds all the pathnames matching specified pattern
import datetime as dt
import random
# !python --version
print('pandas version: ' + pd.__version__)
print('numpy version: ' + np.__version__)
# Out:
# Python 3.9.7pandas version: 1.4.2
#
# numpy version: 1.21.5

# %%
import sys, os
cwd = sys.path[0]
sys.path.append(os.path.join(cwd, 'my_modules'))                # sys.path[0] is dir of the ipynb file
import custom_plot
import data_clean
import data_preprocess
import constants

# %%
# !pip install pytorch-forecasting
# Out:
# Collecting pytorch-forecasting
#   Downloading pytorch_forecasting-0.10.1-py3-none-any.whl (127 kB)
# Requirement already satisfied: torch<2.0,>=1.7 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (1.11.0)
# Requirement already satisfied: scikit-learn<1.1,>=0.24 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (1.0.2)
# Collecting optuna<3.0.0,>=2.3.0
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.2.4 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (1.6.3)
# Requirement already satisfied: scipy in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (3.5.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (1.4.2)
# Requirement already satisfied: statsmodels in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-forecasting) (0.13.2)
# Requirement already satisfied: tqdm in c:\users\s.kaiser\anaconda3\lib\site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting) (4.64.0)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in c:\users\s.kaiser\anaconda3\lib\site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting) (1.22.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting) (1.4.32)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: PyYAML in c:\users\s.kaiser\anaconda3\lib\site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting) (6.0)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from optuna<3.0.0,>=2.3.0->pytorch-forecasting) (21.3)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\s.kaiser\anaconda3\lib\site-packages (from packaging>=20.0->optuna<3.0.0,>=2.3.0->pytorch-forecasting) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pytorch-forecasting) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.3.0->pytorch-forecasting) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\s.kaiser\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.0->pytorch-forecasting) (1.16.0)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.3.2)
# Requirement already satisfied: torchmetrics>=0.4.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.8.2)
# Requirement already satisfied: tensorboard>=2.2.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2.8.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2022.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (4.1.1)
# Requirement already satisfied: aiohttp in c:\users\s.kaiser\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.8.1)
# Requirement already satisfied: requests in c:\users\s.kaiser\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2.27.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from scikit-learn<1.1,>=0.24->pytorch-forecasting) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\s.kaiser\anaconda3\lib\site-packages (from scikit-learn<1.1,>=0.24->pytorch-forecasting) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\s.kaiser\anaconda3\lib\site-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.3.0->pytorch-forecasting) (1.1.1)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.44.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (61.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2.0.3)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.19.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\s.kaiser\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\s.kaiser\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\s.kaiser\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\s.kaiser\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s.kaiser\anaconda3\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s.kaiser\anaconda3\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (3.2.0)
# Requirement already satisfied: colorama in c:\users\s.kaiser\anaconda3\lib\site-packages (from tqdm->optuna<3.0.0,>=2.3.0->pytorch-forecasting) (0.4.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\s.kaiser\anaconda3\lib\site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch-forecasting) (6.0.2)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
# Collecting PrettyTable>=0.7.2
#   Downloading prettytable-3.3.0-py3-none-any.whl (26 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in c:\users\s.kaiser\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch-forecasting) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\s.kaiser\anaconda3\lib\site-packages (from Mako->alembic->optuna<3.0.0,>=2.3.0->pytorch-forecasting) (2.0.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from matplotlib->pytorch-forecasting) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\s.kaiser\anaconda3\lib\site-packages (from matplotlib->pytorch-forecasting) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\s.kaiser\anaconda3\lib\site-packages (from matplotlib->pytorch-forecasting) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\s.kaiser\anaconda3\lib\site-packages (from matplotlib->pytorch-forecasting) (1.3.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\s.kaiser\anaconda3\lib\site-packages (from statsmodels->pytorch-forecasting) (0.5.2)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=f819d65caa95f054d1f4341ae2c5479c27a5e7b942504235de0a9d40465214dc
#   Stored in directory: c:\users\s.kaiser\appdata\local\pip\cache\wheels\0c\09\9e\49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pyreadline3, pyperclip, pbr, stevedore, PrettyTable, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna, pytorch-forecasting
# Successfully installed Mako-1.2.0 PrettyTable-3.3.0 alembic-1.7.7 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 optuna-2.10.0 pbr-5.9.0 pyperclip-1.8.2 pyreadline3-3.4.1 pytorch-forecasting-0.10.1 stevedore-3.5.0

# %%
import copy
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# %%
import sys, os
cwd = sys.path[0]
sys.path.append(os.path.join(cwd, 'my_modules'))

# %%
import sys, os
cwd = sys.path[0]
sys.path.append(os.path.join(cwd, 'my_modules'))                # sys.path[0] is dir of the ipynb file
import custom_plot
import data_clean
import data_preprocess
import constants
# Out:
# imported custom_plot.py
# data_clean imported
# data_preprocess imported

# %%
# read data
import pickle
dir_path = os.path.join(cwd, 'csv')
src_path = os.path.join(dir_path, 'li_ts_valid_cycles_with_cellID.pkl')

with open(src_path, 'rb') as f:
    li_ts_cycles = pickle.load(f)

# %%
print(len(li_ts_cycles))
print(type(li_ts_cycles[36]))
# Out:
# 626
# <class 'pandas.core.frame.DataFrame'>

# %%
# Randomly pick 10 cycles
import random
random.seed(0)
li_random_cycles = random.sample(range(len(li_ts_cycles)), 10)    # randomly pick 10 cycles
print(li_random_cycles)
# Out:
# [394, 430, 41, 265, 523, 497, 414, 310, 488, 366]

# %% [markdown]
# ## Stationarity test
#
# link: https://www.analyticsvidhya.com/blog/2018/09/multivariate-time-series-guide-forecasting-modeling-python-codes/
#
# A Time series is staionary if:
# 1. Mean is constant
# 2. Variance is constant
# 3. No seasonality/periodicity
#
# **WHY**: Passing stationarity test is important for applyng VAR (Vector Autoregression) model or ARIMA (Autoregressive integrated moving average) model. Also, stationary time series will more often give us a better set of predictions.
#
# **How?** Univariate: Augmented Dicky-Fuller test, Multivariate: Johansen's test

# %%
df_temp = li_ts_cycles[li_random_cycles[7]].copy()
print(df_temp)
df_temp.plot()
# Out:
#                  timestamp     V44  current  Temp_mean_module4
# 726590 2022-02-23 07:16:45  4.0261      0.0              215.0
# 726591 2022-02-23 07:16:46  4.0261      0.0              215.0
# 726592 2022-02-23 07:16:47  4.0261      0.0              215.0
# 726593 2022-02-23 07:16:48  4.0261      0.0              215.0
# 726594 2022-02-23 07:16:49  4.0263      0.0              215.0
# ...                    ...     ...      ...                ...
# 79779  2022-02-23 10:34:28  4.1455      0.0              215.0
# 79780  2022-02-23 10:34:29  4.1455      0.0              215.0
# 79781  2022-02-23 10:34:30  4.1455      0.0              215.0
# 79782  2022-02-23 10:34:31  4.1455      0.0              215.0
# 79783  2022-02-23 10:34:32  4.1455      0.0              215.0
#
# [11868 rows x 4 columns]
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <AxesSubplot:>

# %%
#checking stationarity
from statsmodels.tsa.vector_ar.vecm import coint_johansen
df_temp = li_ts_cycles[li_random_cycles[0]].copy()
df_temp = df_temp.drop(['timestamp'], axis=1)
coint_johansen(df_temp,-1,1).eig
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [19], in <cell line: 5>()
#       3 df_temp = li_ts_cycles[li_random_cycles[0]].copy()
#       4 df_temp = df_temp.drop(['timestamp'], axis=1)
# ----> 5 coint_johansen(df_temp,-1,1).eig
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\vector_ar\vecm.py:700, in coint_johansen(endog, det_order, k_ar_diff)
#     698 sk0 = np.dot(rkt.T, r0t) / rkt.shape[0]
#     699 s00 = np.dot(r0t.T, r0t) / r0t.shape[0]
# --> 700 sig = np.dot(sk0, np.dot(inv(s00), sk0.T))
#     701 tmp = inv(skk)
#     702 au, du = np.linalg.eig(np.dot(tmp, sig))  # au is eval, du is evec
#
# File <__array_function__ internals>:5, in inv(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:545, in inv(a)
#     543 signature = 'D->D' if isComplexType(t) else 'd->d'
#     544 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546 return wrap(ainv.astype(result_t, copy=False))
#
# File ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:88, in _raise_linalgerror_singular(err, flag)
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
li_V1 = []
for df_x in li_ts_cycles:    
    # Take one cell data to avoid time overlap
    if 'V1' in df_x:
        li_V1.append(df_x)

# %%
li_V60 = []
for df_x in li_ts_cycles:    
    # Take one cell data to avoid time overlap
    if 'V60' in df_x:
        li_V60.append(df_x)

# %%
# %matplotlib notebook

for df_each in li_V1:
    df_temp = df_each.copy()
#     plot_xy((df_temp['elapsed_sec'], "Time (s)"), (df_temp['V1'], "V1"))
    custom_plot.plot_dual_axis((df_temp['timestamp'], "Time"), (df_temp['current'], "current"), (df_temp['V1'], "voltage_cell1"))
    df_temp = np.nan
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [25], in <cell line: 3>()
#       4     df_temp = df_each.copy()
#       5 #     plot_xy((df_temp['elapsed_sec'], "Time (s)"), (df_temp['V1'], "V1"))
# ----> 6     custom_plot.plot_dual_axis((df_temp['timestamp'], "Time"), (df_temp['current'], "current"), (df_temp['V1'], "voltage_cell1"))
#       7     df_temp = np.nan
#
# File ~\Experiments\MuleCarData\my_modules\custom_plot.py:42, in plot_dual_axis(*axes)
#      40 plt.show()
#      41 # fig.canvas.get_supported_filetypes() # shows all supported file types
# ---> 42 fig.savefig('my_figure.eps')
#
# File ~\Anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_ps.py:847, in FigureCanvasPS.print_eps(self, outfile, *args, **kwargs)
#     845 @_api.delete_parameter("3.5", "args")
#     846 def print_eps(self, outfile, *args, **kwargs):
# --> 847     return self._print_ps(outfile, 'eps', **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_ps.py:888, in FigureCanvasPS._print_ps(self, outfile, format, dpi, metadata, papertype, orientation, **kwargs)
#     882 orientation = _api.check_getitem(
#     883     _Orientation, orientation=orientation.lower())
#     885 printer = (self._print_figure_tex
#     886            if mpl.rcParams['text.usetex'] else
#     887            self._print_figure)
# --> 888 printer(outfile, format, dpi=dpi, dsc_comments=dsc_comments,
#     889         orientation=orientation, papertype=papertype, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_ps.py:1024, in FigureCanvasPS._print_figure(self, outfile, format, dpi, dsc_comments, orientation, papertype, bbox_inches_restore)
#    1021         _move_path_to_path_or_stream(tmpfile, outfile)
#    1023 else:  # Write directly to outfile.
# -> 1024     with cbook.open_file_cm(outfile, "w", encoding="latin-1") as file:
#    1025         if not file_requires_unicode(file):
#    1026             file = codecs.getwriter("latin-1")(file)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:465, in open_file_cm(path_or_file, mode, encoding)
#     463 def open_file_cm(path_or_file, mode="r", encoding=None):
#     464     r"""Pass through file objects and context-manage path-likes."""
# --> 465     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     466     return fh if opened else contextlib.nullcontext(fh)
#
# File ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# PermissionError: [Errno 13] Permission denied: 'my_figure.eps'

# %%
print(li_V1[0])
# Out:
#                   timestamp      V1  current  Temp_mean_module1
# 1096325 2022-01-18 13:02:17  4.1430      0.0               12.0
# 1096326 2022-01-18 13:02:18  4.1400      0.0               13.0
# 965787  2022-01-18 13:02:19  4.1400      0.0               13.0
# 965788  2022-01-18 13:02:20  4.1400      0.0               13.0
# 965789  2022-01-18 13:02:21  4.1400      0.0               13.0
# ...                     ...     ...      ...                ...
# 966664  2022-01-18 13:16:56  4.0810      0.0               13.0
# 966665  2022-01-18 13:16:57  4.0810      0.0               13.0
# 1097206 2022-01-18 13:16:58  4.0810      0.0               13.0
# 1097207 2022-01-18 13:16:59  4.0811      0.0               13.0
# 1097208 2022-01-18 13:17:00  4.0811      0.0               13.0
#
# [884 rows x 4 columns]

# %%
df_connected_V1 = pd.concat(li_V1)
df_connected_V1['timestamp'].is_monotonic_increasing
# Out:
# True

# %%
df_connected_V1["time_idx"] = df_connected_V1['timestamp'].dt.second

# %%
print(df_connected_V1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(df_connected_V1)
#
# NameError: name 'df_connected_V1' is not defined

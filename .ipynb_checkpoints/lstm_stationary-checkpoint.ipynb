# %%
# increase default window size for notebook
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# C:\Users\s.kaiser\AppData\Local\Temp\ipykernel_19968\696421802.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %%
# Set reproducible results by random seeding, answer from here: https://stackoverflow.com/questions/50659482/why-cant-i-get-reproducible-results-in-keras-even-though-i-set-the-random-seeds

# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)

# 5. Configure a new global `tensorflow` session
from keras import backend as K

# for later versions:
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)
K.set_session(sess)
# Out:
# WARNING:tensorflow:From C:\Users\s.kaiser\AppData\Local\Temp\ipykernel_19968\2006800096.py:29: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import timeit
from datetime import timedelta
from dataclasses import dataclass       # C like structure
import glob                             # finds all the pathnames matching specified pattern
import datetime as dt
import random
# !python --version
print('pandas version: ' + pd.__version__)
print('numpy version: ' + np.__version__)
# Out:
# Python 3.9.7
# pandas version: 1.4.2
# numpy version: 1.21.5

# %%
import sys, os
cwd = sys.path[0]
sys.path.append(os.path.join(cwd, 'my_modules'))                # sys.path[0] is dir of the ipynb file
import custom_plot
import data_clean
import data_preprocess
import constants
# Out:
# imported custom_plot.py
# data_clean imported
# data_preprocess imported

# %%
# %matplotlib notebook
# Plot related packages,%matplotlib notebook makes plots in jupyter interactive
# constants for plotting
x_label_elapsedtime = 0
x_label_datetime = 1

# %%
import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError
from tensorflow.keras.optimizers import Adam


from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation, Dropout
from keras.models import Sequential

from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
# Load processed data (phase 1)

dir_path = os.path.join(cwd, 'csv')
filename = 'cell_cycles.pkl'

# load last saved df from phase1 data and convert time stamp and sort
li_ts_cycles_ph1 = data_preprocess.load_object(dir_path, filename)

# %%
# Load processed data (phase 2)
dir_path = os.path.join(cwd, 'csv', 'phase_2_pkl')
filename = 'mod1_cell_cycles.pkl'
li_ts_cycles_ph2 = data_preprocess.load_object(dir_path, filename)

# %%
# Combine phase1 and phase 2 data
import math

# for x, y in li_ts_cycles_ph1:
#     print('phase1 cells', x, y)
    
# for x, y in li_ts_cycles_ph2:
#     print('phase2 cells', len(y))

combined_phase_cycles = []
if len(li_ts_cycles_ph1) <= len(li_ts_cycles_ph2):
    for i in range(len(li_ts_cycles_ph1)):              # each cell contain multiple cycles
        c_1, cycles_1 = li_ts_cycles_ph1[i]                 # for example, (v1, [cycles])
        c_2, cycles_2 = li_ts_cycles_ph2[i]
        if (c_2 == c_1):
            cycles_1 += cycles_2                        # this adds cycle to li_ts_cycles_ph1
    combined_phase_cycles = li_ts_cycles_ph1
else:
    for i in range(len(li_ts_cycles_ph2)):              # each cell contain multiple cycles
        c_2, cycles_2 = li_ts_cycles_ph2[i]
        c_1, cycles_1 = li_ts_cycles_ph1[i]
        if (c_2 == c_1):
            cycles_2 += cycles_1                        # this adds cycle to li_ts_cycles
    combined_phase_cycles = li_ts_cycles_ph2


for x, y in combined_phase_cycles:
    print('combined cells', x)
# Out:
# combined cells V1
# combined cells V2
# combined cells V3
# combined cells V4
# combined cells V5
# combined cells V6
# combined cells V7
# combined cells V8
# combined cells V9
# combined cells V10
# combined cells V11
# combined cells V12

# %%
import math

# Separate training, validation and test cycles, keep cycles without cell ID
TRAIN_SAMPLES = 0.9
li_train_cycles = []      # each of this list is a separate static_dynamic_static cycle
# li_validation_cycles = []
li_test_cycles= []
counter = 0

total_cycles = 0
for (c, li_cycles) in combined_phase_cycles:              # each cell contain multiple cycles
    counter += 1
    num_cell_cycles = len(li_cycles)
    num_train_cycles = math.floor(num_cell_cycles * TRAIN_SAMPLES)                 # training cycle samples 70%
    # num_validation_cycles = math.ceil((num_cell_cycles - num_train_cycles) * 0.5)
    # num_test_cycles = num_cell_cycles - num_validation_cycles - num_train_cycles
    num_test_cycles = num_cell_cycles - num_train_cycles
    total_cycles += len(li_cycles)
    # print(num_cell_cycles, num_train_cycles, num_validation_cycles, num_test_cycles)

    li_train_cycles += li_cycles[0:num_train_cycles]
    # li_validation_cycles += li_cycles[num_train_cycles:num_train_cycles+num_validation_cycles]
    # li_test_cycles += li_cycles[num_train_cycles+num_validation_cycles:]
    li_test_cycles += li_cycles[num_train_cycles:]
    break

print(total_cycles, len(li_train_cycles), len(li_test_cycles))     # test
# Out:
# 17 15 2

# %% [markdown]
# ### univariate: current to voltage mapping

# %%
# Make dataset ready for LSTM
# [temporal input sequence] [output]
# example:
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_supervised_univariate(df_feature, df_label, window_size=1):
    df_feature_as_np = df_feature.to_numpy()
    df_label_as_np = df_label.to_numpy()
    X = []
    y = []
    total_rows = len(df_feature_as_np) - window_size + 1
    for i in range(len(df_feature_as_np) - window_size):
        row = [[a] for a in df_feature_as_np[i:i+window_size]]
        X.append(row)
        label = df_label_as_np[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

TIMESTEPS = 10
# One sample only
# df = li_train_cycles[2].copy()
# df = df[['V', 'current', 'Temp']]


# concat all train and test cycles
frames = []

for df in li_train_cycles:
    df_each = df.copy()
    frames.append(df_each)

df = pd.concat(frames)
# print(df)

# statndard
df['V_standard'] = StandardScaler().fit_transform(df[['V']])
df['cur_standard'] = StandardScaler().fit_transform(df[['current']])

# normnal
df['V_normal'] = MinMaxScaler().fit_transform(df[['V']])
df['cur_normal'] = MinMaxScaler().fit_transform(df[['current']])

# reverse data before training, for test
# df = df.iloc[::-1]
# df1 = df.loc[df['contactor_state'] == 2]               # take only dynamic voltage

X, y = df_to_supervised_univariate(df['cur_standard'], df['V_standard'], TIMESTEPS)     # standard
# X, y = df_to_supervised_univariate(df['cur_normal'], df['V_normal'], TIMESTEPS)     # normal
# X, y = df_to_supervised_univariate(df['current'], df['V'], TIMESTEPS)     # without normalization
print(X.shape, y.shape)
# Out:
# (48841, 10, 1) (48841,)

# %%
# %matplotlib notebook

# Import seaborn
import seaborn as sns

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))
sns.histplot(x=df['current'], ax=ax[0])
ax[0].set_title('Original Current')
sns.histplot(x=df['cur_normal'], ax=ax[1])
ax[1].set_title('Normalized')
sns.histplot(x=df['cur_standard'], ax=ax[2])
ax[2].set_title('Standardized')

for i in range(3):
    ax[i].set_xlim([-50, 50])
plt.show()

# df_sine.drop(['feature_normalized', 'feature_standardized'], axis=1, inplace=True)
# Out:
# <img src="data:image/png;base64,..." width="1342.7272436244434">

# %%
NUM_EPOCHS = 2000
NUM_NEURONS = 64

def stacked_dropout_LSTM(path, train_X, train_y, iteration_no, num_neurons=32, dropout=0):
    # Seeds
    tf.keras.backend.clear_session()
    seed_value= 0
    os.environ['PYTHONHASHSEED']=str(seed_value)
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)
    session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
    tf.compat.v1.keras.backend.set_session(sess)
    K.set_session(sess)

#     model = Sequential()
#     model.add(LSTM(num_neurons, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))   # no use of batch because stateless, input shape=(#samples, #fatures)
#     model.add(LSTM(units=100, return_sequences=False))
#     model.add(Dense(10, 'relu'))
#     model.add(Dense(1, 'linear'))
#     model.summary()

    # LSTM arch same as before
    model = Sequential()
    model.add(LSTM(num_neurons, input_shape=(train_X.shape[1], train_X.shape[2])))   # no use of batch because stateless, input shape=(#samples, #fatures)
#     model.add(Dense(8, 'relu'))
    model.add(Dense(1, 'linear'))
    model.summary()

    # save_best_only=true saves the best model with lowest validation loss
    model_path = os.path.join(path, 'model' + str(iteration_no) + '.h5')
    my_callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=100,verbose=0,mode='min'),  # minimize validation loss
        tf.keras.callbacks.ModelCheckpoint(filepath=model_path, monitor='val_loss', mode='min', save_best_only=True)
    ]

    model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

    # measuers performance on every epoch on the validation dataset
    # calls back checkpoint after every epoch and saves model if validation loss is lower than before
    # history = model.fit(train_X, train_y, validation_data=(val_X, val_y), epochs=nb_epoch, callbacks=callback_list)

    history = model.fit(train_X, train_y, epochs=NUM_EPOCHS, verbose=2, shuffle=False, validation_split=0.20, callbacks=my_callbacks)
    data_preprocess.save_object(history, path, 'history' + str(iteration_no) + '.pkl')    # save history

# Train Generic RNN model
model_path = os.path.join(cwd, 'generalized', 'stationary')
stacked_dropout_LSTM(model_path, X, y, '_standard_', NUM_NEURONS, 0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/2000
# 1221/1221 - 8s - loss: 0.4289 - root_mean_squared_error: 0.6549 - val_loss: 1.8532 - val_root_mean_squared_error: 1.3613 - 8s/epoch - 6ms/step
# Epoch 2/2000
# 1221/1221 - 7s - loss: 0.4624 - root_mean_squared_error: 0.6800 - val_loss: 1.9168 - val_root_mean_squared_error: 1.3845 - 7s/epoch - 6ms/step
# Epoch 3/2000
# 1221/1221 - 5s - loss: 0.4577 - root_mean_squared_error: 0.6765 - val_loss: 1.9376 - val_root_mean_squared_error: 1.3920 - 5s/epoch - 4ms/step
# Epoch 4/2000
# 1221/1221 - 6s - loss: 0.4541 - root_mean_squared_error: 0.6739 - val_loss: 1.9504 - val_root_mean_squared_error: 1.3966 - 6s/epoch - 5ms/step
# Epoch 5/2000
# 1221/1221 - 5s - loss: 0.4519 - root_mean_squared_error: 0.6722 - val_loss: 1.9625 - val_root_mean_squared_error: 1.4009 - 5s/epoch - 4ms/step
# Epoch 6/2000
# 1221/1221 - 5s - loss: 0.4500 - root_mean_squared_error: 0.6708 - val_loss: 1.9696 - val_root_mean_squared_error: 1.4034 - 5s/epoch - 4ms/step
# Epoch 7/2000
# 1221/1221 - 5s - loss: 0.4471 - root_mean_squared_error: 0.6687 - val_loss: 1.9779 - val_root_mean_squared_error: 1.4064 - 5s/epoch - 4ms/step
# Epoch 8/2000
# 1221/1221 - 6s - loss: 0.4473 - root_mean_squared_error: 0.6688 - val_loss: 1.9834 - val_root_mean_squared_error: 1.4083 - 6s/epoch - 5ms/step
# Epoch 9/2000
# 1221/1221 - 5s - loss: 0.4453 - root_mean_squared_error: 0.6673 - val_loss: 1.9894 - val_root_mean_squared_error: 1.4105 - 5s/epoch - 4ms/step
# Epoch 10/2000
# 1221/1221 - 6s - loss: 0.4425 - root_mean_squared_error: 0.6652 - val_loss: 1.9786 - val_root_mean_squared_error: 1.4066 - 6s/epoch - 5ms/step
# Epoch 11/2000
# 1221/1221 - 6s - loss: 0.4443 - root_mean_squared_error: 0.6666 - val_loss: 2.0002 - val_root_mean_squared_error: 1.4143 - 6s/epoch - 5ms/step
# Epoch 12/2000
# 1221/1221 - 6s - loss: 0.4371 - root_mean_squared_error: 0.6611 - val_loss: 1.9754 - val_root_mean_squared_error: 1.4055 - 6s/epoch - 5ms/step
# Epoch 13/2000
# 1221/1221 - 7s - loss: 0.4405 - root_mean_squared_error: 0.6637 - val_loss: 1.9938 - val_root_mean_squared_error: 1.4120 - 7s/epoch - 6ms/step
# Epoch 14/2000
# 1221/1221 - 7s - loss: 0.4346 - root_mean_squared_error: 0.6593 - val_loss: 1.9870 - val_root_mean_squared_error: 1.4096 - 7s/epoch - 6ms/step
# Epoch 15/2000
# 1221/1221 - 7s - loss: 0.4335 - root_mean_squared_error: 0.6584 - val_loss: 1.9863 - val_root_mean_squared_error: 1.4094 - 7s/epoch - 6ms/step
# Epoch 16/2000
# 1221/1221 - 8s - loss: 0.4305 - root_mean_squared_error: 0.6561 - val_loss: 1.9806 - val_root_mean_squared_error: 1.4073 - 8s/epoch - 6ms/step
# Epoch 17/2000
# 1221/1221 - 8s - loss: 0.4278 - root_mean_squared_error: 0.6540 - val_loss: 1.9785 - val_root_mean_squared_error: 1.4066 - 8s/epoch - 6ms/step
# Epoch 18/2000
# 1221/1221 - 8s - loss: 0.4235 - root_mean_squared_error: 0.6508 - val_loss: 1.9678 - val_root_mean_squared_error: 1.4028 - 8s/epoch - 7ms/step
# Epoch 19/2000
# 1221/1221 - 10s - loss: 0.4219 - root_mean_squared_error: 0.6495 - val_loss: 1.9674 - val_root_mean_squared_error: 1.4026 - 10s/epoch - 8ms/step
# Epoch 20/2000
# 1221/1221 - 6s - loss: 0.4185 - root_mean_squared_error: 0.6469 - val_loss: 1.9613 - val_root_mean_squared_error: 1.4005 - 6s/epoch - 5ms/step
# Epoch 21/2000
# 1221/1221 - 10s - loss: 0.4148 - root_mean_squared_error: 0.6440 - val_loss: 1.9576 - val_root_mean_squared_error: 1.3991 - 10s/epoch - 8ms/step
# Epoch 22/2000
# 1221/1221 - 10s - loss: 0.4115 - root_mean_squared_error: 0.6415 - val_loss: 1.9507 - val_root_mean_squared_error: 1.3967 - 10s/epoch - 8ms/step
# Epoch 23/2000
# 1221/1221 - 10s - loss: 0.4096 - root_mean_squared_error: 0.6400 - val_loss: 1.9519 - val_root_mean_squared_error: 1.3971 - 10s/epoch - 8ms/step
# Epoch 24/2000
# 1221/1221 - 10s - loss: 0.4051 - root_mean_squared_error: 0.6365 - val_loss: 1.9467 - val_root_mean_squared_error: 1.3952 - 10s/epoch - 8ms/step
# Epoch 25/2000
# 1221/1221 - 10s - loss: 0.4021 - root_mean_squared_error: 0.6341 - val_loss: 1.9468 - val_root_mean_squared_error: 1.3953 - 10s/epoch - 8ms/step
# Epoch 26/2000
# 1221/1221 - 9s - loss: 0.3980 - root_mean_squared_error: 0.6309 - val_loss: 1.9438 - val_root_mean_squared_error: 1.3942 - 9s/epoch - 8ms/step
# Epoch 27/2000
# 1221/1221 - 10s - loss: 0.3950 - root_mean_squared_error: 0.6285 - val_loss: 1.9433 - val_root_mean_squared_error: 1.3940 - 10s/epoch - 8ms/step
# Epoch 28/2000
# 1221/1221 - 9s - loss: 0.3905 - root_mean_squared_error: 0.6249 - val_loss: 1.9407 - val_root_mean_squared_error: 1.3931 - 9s/epoch - 7ms/step
# Epoch 29/2000
# 1221/1221 - 9s - loss: 0.3874 - root_mean_squared_error: 0.6224 - val_loss: 1.9383 - val_root_mean_squared_error: 1.3922 - 9s/epoch - 7ms/step
# Epoch 30/2000
# 1221/1221 - 9s - loss: 0.3842 - root_mean_squared_error: 0.6199 - val_loss: 1.9333 - val_root_mean_squared_error: 1.3904 - 9s/epoch - 8ms/step
# Epoch 31/2000
# 1221/1221 - 9s - loss: 0.3808 - root_mean_squared_error: 0.6171 - val_loss: 1.9258 - val_root_mean_squared_error: 1.3877 - 9s/epoch - 7ms/step
# Epoch 32/2000
# 1221/1221 - 9s - loss: 0.3771 - root_mean_squared_error: 0.6141 - val_loss: 1.9154 - val_root_mean_squared_error: 1.3840 - 9s/epoch - 7ms/step
# Epoch 33/2000
# 1221/1221 - 10s - loss: 0.3736 - root_mean_squared_error: 0.6112 - val_loss: 1.9024 - val_root_mean_squared_error: 1.3793 - 10s/epoch - 8ms/step
# Epoch 34/2000
# 1221/1221 - 9s - loss: 0.3696 - root_mean_squared_error: 0.6080 - val_loss: 1.8879 - val_root_mean_squared_error: 1.3740 - 9s/epoch - 7ms/step
# Epoch 35/2000
# 1221/1221 - 10s - loss: 0.3657 - root_mean_squared_error: 0.6047 - val_loss: 1.8735 - val_root_mean_squared_error: 1.3687 - 10s/epoch - 8ms/step
# Epoch 36/2000
# 1221/1221 - 10s - loss: 0.3622 - root_mean_squared_error: 0.6018 - val_loss: 1.8601 - val_root_mean_squared_error: 1.3639 - 10s/epoch - 8ms/step
# Epoch 37/2000
# 1221/1221 - 9s - loss: 0.3594 - root_mean_squared_error: 0.5995 - val_loss: 1.8487 - val_root_mean_squared_error: 1.3597 - 9s/epoch - 8ms/step
# Epoch 38/2000
# 1221/1221 - 10s - loss: 0.3575 - root_mean_squared_error: 0.5979 - val_loss: 1.8395 - val_root_mean_squared_error: 1.3563 - 10s/epoch - 9ms/step
# Epoch 39/2000
# 1221/1221 - 11s - loss: 0.3562 - root_mean_squared_error: 0.5968 - val_loss: 1.8318 - val_root_mean_squared_error: 1.3534 - 11s/epoch - 9ms/step
# Epoch 40/2000
# 1221/1221 - 11s - loss: 0.3552 - root_mean_squared_error: 0.5960 - val_loss: 1.8252 - val_root_mean_squared_error: 1.3510 - 11s/epoch - 9ms/step
# Epoch 41/2000
# 1221/1221 - 10s - loss: 0.3545 - root_mean_squared_error: 0.5954 - val_loss: 1.8195 - val_root_mean_squared_error: 1.3489 - 10s/epoch - 8ms/step
# Epoch 42/2000
# 1221/1221 - 9s - loss: 0.3539 - root_mean_squared_error: 0.5949 - val_loss: 1.8146 - val_root_mean_squared_error: 1.3471 - 9s/epoch - 7ms/step
# Epoch 43/2000
# 1221/1221 - 9s - loss: 0.3534 - root_mean_squared_error: 0.5945 - val_loss: 1.8102 - val_root_mean_squared_error: 1.3455 - 9s/epoch - 7ms/step
# Epoch 44/2000
# 1221/1221 - 9s - loss: 0.3531 - root_mean_squared_error: 0.5942 - val_loss: 1.8066 - val_root_mean_squared_error: 1.3441 - 9s/epoch - 7ms/step
# Epoch 45/2000
# 1221/1221 - 9s - loss: 0.3527 - root_mean_squared_error: 0.5939 - val_loss: 1.8034 - val_root_mean_squared_error: 1.3429 - 9s/epoch - 7ms/step
# Epoch 46/2000
# 1221/1221 - 9s - loss: 0.3524 - root_mean_squared_error: 0.5936 - val_loss: 1.8009 - val_root_mean_squared_error: 1.3420 - 9s/epoch - 8ms/step
# Epoch 47/2000
# 1221/1221 - 10s - loss: 0.3522 - root_mean_squared_error: 0.5934 - val_loss: 1.7986 - val_root_mean_squared_error: 1.3411 - 10s/epoch - 8ms/step
# Epoch 48/2000
# 1221/1221 - 9s - loss: 0.3519 - root_mean_squared_error: 0.5932 - val_loss: 1.7967 - val_root_mean_squared_error: 1.3404 - 9s/epoch - 8ms/step
# Epoch 49/2000
# 1221/1221 - 10s - loss: 0.3516 - root_mean_squared_error: 0.5930 - val_loss: 1.7951 - val_root_mean_squared_error: 1.3398 - 10s/epoch - 8ms/step
# Epoch 50/2000
# 1221/1221 - 9s - loss: 0.3513 - root_mean_squared_error: 0.5927 - val_loss: 1.7936 - val_root_mean_squared_error: 1.3393 - 9s/epoch - 7ms/step
# Epoch 51/2000
# 1221/1221 - 9s - loss: 0.3511 - root_mean_squared_error: 0.5925 - val_loss: 1.7922 - val_root_mean_squared_error: 1.3387 - 9s/epoch - 7ms/step
# Epoch 52/2000
# 1221/1221 - 9s - loss: 0.3508 - root_mean_squared_error: 0.5922 - val_loss: 1.7911 - val_root_mean_squared_error: 1.3383 - 9s/epoch - 7ms/step
# Epoch 53/2000
# 1221/1221 - 9s - loss: 0.3504 - root_mean_squared_error: 0.5920 - val_loss: 1.7902 - val_root_mean_squared_error: 1.3380 - 9s/epoch - 7ms/step
# Epoch 54/2000
# 1221/1221 - 9s - loss: 0.3501 - root_mean_squared_error: 0.5917 - val_loss: 1.7894 - val_root_mean_squared_error: 1.3377 - 9s/epoch - 7ms/step
# Epoch 55/2000
# 1221/1221 - 10s - loss: 0.3498 - root_mean_squared_error: 0.5915 - val_loss: 1.7887 - val_root_mean_squared_error: 1.3374 - 10s/epoch - 8ms/step
# Epoch 56/2000
# 1221/1221 - 9s - loss: 0.3495 - root_mean_squared_error: 0.5912 - val_loss: 1.7884 - val_root_mean_squared_error: 1.3373 - 9s/epoch - 7ms/step
# Epoch 57/2000
# 1221/1221 - 10s - loss: 0.3492 - root_mean_squared_error: 0.5909 - val_loss: 1.7881 - val_root_mean_squared_error: 1.3372 - 10s/epoch - 8ms/step
# Epoch 58/2000
# 1221/1221 - 9s - loss: 0.3490 - root_mean_squared_error: 0.5907 - val_loss: 1.7877 - val_root_mean_squared_error: 1.3371 - 9s/epoch - 8ms/step
# Epoch 59/2000
# 1221/1221 - 10s - loss: 0.3487 - root_mean_squared_error: 0.5905 - val_loss: 1.7877 - val_root_mean_squared_error: 1.3370 - 10s/epoch - 8ms/step
# Epoch 60/2000
# 1221/1221 - 9s - loss: 0.3484 - root_mean_squared_error: 0.5903 - val_loss: 1.7876 - val_root_mean_squared_error: 1.3370 - 9s/epoch - 7ms/step
# Epoch 61/2000
# 1221/1221 - 9s - loss: 0.3482 - root_mean_squared_error: 0.5901 - val_loss: 1.7878 - val_root_mean_squared_error: 1.3371 - 9s/epoch - 8ms/step
# Epoch 62/2000
# 1221/1221 - 10s - loss: 0.3480 - root_mean_squared_error: 0.5899 - val_loss: 1.7881 - val_root_mean_squared_error: 1.3372 - 10s/epoch - 8ms/step
# Epoch 63/2000
# 1221/1221 - 9s - loss: 0.3478 - root_mean_squared_error: 0.5897 - val_loss: 1.7883 - val_root_mean_squared_error: 1.3373 - 9s/epoch - 8ms/step
# Epoch 64/2000
# 1221/1221 - 8s - loss: 0.3475 - root_mean_squared_error: 0.5895 - val_loss: 1.7886 - val_root_mean_squared_error: 1.3374 - 8s/epoch - 7ms/step
# Epoch 65/2000
# 1221/1221 - 10s - loss: 0.3474 - root_mean_squared_error: 0.5894 - val_loss: 1.7889 - val_root_mean_squared_error: 1.3375 - 10s/epoch - 8ms/step
# Epoch 66/2000
# 1221/1221 - 8s - loss: 0.3472 - root_mean_squared_error: 0.5892 - val_loss: 1.7890 - val_root_mean_squared_error: 1.3375 - 8s/epoch - 7ms/step
# Epoch 67/2000
# 1221/1221 - 9s - loss: 0.3470 - root_mean_squared_error: 0.5891 - val_loss: 1.7893 - val_root_mean_squared_error: 1.3377 - 9s/epoch - 8ms/step
# Epoch 68/2000
# 1221/1221 - 9s - loss: 0.3468 - root_mean_squared_error: 0.5889 - val_loss: 1.7893 - val_root_mean_squared_error: 1.3376 - 9s/epoch - 8ms/step
# Epoch 69/2000
# 1221/1221 - 10s - loss: 0.3466 - root_mean_squared_error: 0.5887 - val_loss: 1.7896 - val_root_mean_squared_error: 1.3378 - 10s/epoch - 8ms/step
# Epoch 70/2000
# 1221/1221 - 10s - loss: 0.3464 - root_mean_squared_error: 0.5885 - val_loss: 1.7902 - val_root_mean_squared_error: 1.3380 - 10s/epoch - 8ms/step
# Epoch 71/2000
# 1221/1221 - 8s - loss: 0.3462 - root_mean_squared_error: 0.5884 - val_loss: 1.7908 - val_root_mean_squared_error: 1.3382 - 8s/epoch - 7ms/step
# Epoch 72/2000
# 1221/1221 - 10s - loss: 0.3460 - root_mean_squared_error: 0.5882 - val_loss: 1.7913 - val_root_mean_squared_error: 1.3384 - 10s/epoch - 8ms/step
# Epoch 73/2000
# 1221/1221 - 10s - loss: 0.3458 - root_mean_squared_error: 0.5880 - val_loss: 1.7921 - val_root_mean_squared_error: 1.3387 - 10s/epoch - 8ms/step
# Epoch 74/2000
# 1221/1221 - 10s - loss: 0.3455 - root_mean_squared_error: 0.5878 - val_loss: 1.7929 - val_root_mean_squared_error: 1.3390 - 10s/epoch - 8ms/step
# Epoch 75/2000
# 1221/1221 - 9s - loss: 0.3453 - root_mean_squared_error: 0.5876 - val_loss: 1.7936 - val_root_mean_squared_error: 1.3393 - 9s/epoch - 8ms/step
# Epoch 76/2000
# 1221/1221 - 10s - loss: 0.3451 - root_mean_squared_error: 0.5875 - val_loss: 1.7945 - val_root_mean_squared_error: 1.3396 - 10s/epoch - 8ms/step
# Epoch 77/2000
# 1221/1221 - 9s - loss: 0.3449 - root_mean_squared_error: 0.5873 - val_loss: 1.7948 - val_root_mean_squared_error: 1.3397 - 9s/epoch - 8ms/step
# Epoch 78/2000
# 1221/1221 - 9s - loss: 0.3447 - root_mean_squared_error: 0.5871 - val_loss: 1.7958 - val_root_mean_squared_error: 1.3401 - 9s/epoch - 7ms/step
# Epoch 79/2000
# 1221/1221 - 10s - loss: 0.3445 - root_mean_squared_error: 0.5869 - val_loss: 1.7971 - val_root_mean_squared_error: 1.3406 - 10s/epoch - 8ms/step
# Epoch 80/2000
# 1221/1221 - 10s - loss: 0.3443 - root_mean_squared_error: 0.5867 - val_loss: 1.7985 - val_root_mean_squared_error: 1.3411 - 10s/epoch - 8ms/step
# Epoch 81/2000
# 1221/1221 - 9s - loss: 0.3440 - root_mean_squared_error: 0.5865 - val_loss: 1.7990 - val_root_mean_squared_error: 1.3413 - 9s/epoch - 7ms/step
# Epoch 82/2000
# 1221/1221 - 9s - loss: 0.3438 - root_mean_squared_error: 0.5863 - val_loss: 1.7994 - val_root_mean_squared_error: 1.3414 - 9s/epoch - 8ms/step
# Epoch 83/2000
# 1221/1221 - 10s - loss: 0.3435 - root_mean_squared_error: 0.5861 - val_loss: 1.7996 - val_root_mean_squared_error: 1.3415 - 10s/epoch - 8ms/step
# Epoch 84/2000
# 1221/1221 - 9s - loss: 0.3433 - root_mean_squared_error: 0.5859 - val_loss: 1.7999 - val_root_mean_squared_error: 1.3416 - 9s/epoch - 8ms/step
# Epoch 85/2000
# 1221/1221 - 9s - loss: 0.3431 - root_mean_squared_error: 0.5857 - val_loss: 1.8003 - val_root_mean_squared_error: 1.3417 - 9s/epoch - 8ms/step
# Epoch 86/2000
# 1221/1221 - 9s - loss: 0.3428 - root_mean_squared_error: 0.5855 - val_loss: 1.8010 - val_root_mean_squared_error: 1.3420 - 9s/epoch - 8ms/step
# Epoch 87/2000
# 1221/1221 - 9s - loss: 0.3426 - root_mean_squared_error: 0.5853 - val_loss: 1.8013 - val_root_mean_squared_error: 1.3421 - 9s/epoch - 8ms/step
# Epoch 88/2000
# 1221/1221 - 9s - loss: 0.3423 - root_mean_squared_error: 0.5851 - val_loss: 1.8016 - val_root_mean_squared_error: 1.3422 - 9s/epoch - 8ms/step
# Epoch 89/2000
# 1221/1221 - 10s - loss: 0.3420 - root_mean_squared_error: 0.5848 - val_loss: 1.8018 - val_root_mean_squared_error: 1.3423 - 10s/epoch - 8ms/step
# Epoch 90/2000
# 1221/1221 - 9s - loss: 0.3418 - root_mean_squared_error: 0.5846 - val_loss: 1.8023 - val_root_mean_squared_error: 1.3425 - 9s/epoch - 7ms/step
# Epoch 91/2000
# 1221/1221 - 10s - loss: 0.3415 - root_mean_squared_error: 0.5844 - val_loss: 1.8026 - val_root_mean_squared_error: 1.3426 - 10s/epoch - 8ms/step
# Epoch 92/2000
# 1221/1221 - 10s - loss: 0.3413 - root_mean_squared_error: 0.5842 - val_loss: 1.8031 - val_root_mean_squared_error: 1.3428 - 10s/epoch - 8ms/step
# Epoch 93/2000
# 1221/1221 - 9s - loss: 0.3410 - root_mean_squared_error: 0.5840 - val_loss: 1.8035 - val_root_mean_squared_error: 1.3430 - 9s/epoch - 8ms/step
# Epoch 94/2000
# 1221/1221 - 9s - loss: 0.3408 - root_mean_squared_error: 0.5837 - val_loss: 1.8038 - val_root_mean_squared_error: 1.3430 - 9s/epoch - 8ms/step
# Epoch 95/2000
# 1221/1221 - 10s - loss: 0.3405 - root_mean_squared_error: 0.5835 - val_loss: 1.8041 - val_root_mean_squared_error: 1.3432 - 10s/epoch - 8ms/step
# Epoch 96/2000
# 1221/1221 - 10s - loss: 0.3403 - root_mean_squared_error: 0.5833 - val_loss: 1.8042 - val_root_mean_squared_error: 1.3432 - 10s/epoch - 8ms/step
# Epoch 97/2000
# 1221/1221 - 9s - loss: 0.3400 - root_mean_squared_error: 0.5831 - val_loss: 1.8044 - val_root_mean_squared_error: 1.3433 - 9s/epoch - 8ms/step
# Epoch 98/2000
# 1221/1221 - 10s - loss: 0.3398 - root_mean_squared_error: 0.5829 - val_loss: 1.8045 - val_root_mean_squared_error: 1.3433 - 10s/epoch - 8ms/step
# Epoch 99/2000
# 1221/1221 - 9s - loss: 0.3395 - root_mean_squared_error: 0.5827 - val_loss: 1.8045 - val_root_mean_squared_error: 1.3433 - 9s/epoch - 7ms/step
# Epoch 100/2000
# 1221/1221 - 10s - loss: 0.3393 - root_mean_squared_error: 0.5825 - val_loss: 1.8044 - val_root_mean_squared_error: 1.3433 - 10s/epoch - 8ms/step
# Epoch 101/2000
# 1221/1221 - 8s - loss: 0.3391 - root_mean_squared_error: 0.5823 - val_loss: 1.8046 - val_root_mean_squared_error: 1.3433 - 8s/epoch - 7ms/step
# Epoch 102/2000
# 1221/1221 - 10s - loss: 0.3388 - root_mean_squared_error: 0.5821 - val_loss: 1.8047 - val_root_mean_squared_error: 1.3434 - 10s/epoch - 8ms/step
# Epoch 103/2000
# 1221/1221 - 10s - loss: 0.3386 - root_mean_squared_error: 0.5819 - val_loss: 1.8049 - val_root_mean_squared_error: 1.3435 - 10s/epoch - 8ms/step
# Epoch 104/2000
# 1221/1221 - 8s - loss: 0.3383 - root_mean_squared_error: 0.5817 - val_loss: 1.8051 - val_root_mean_squared_error: 1.3435 - 8s/epoch - 7ms/step
# Epoch 105/2000
# 1221/1221 - 10s - loss: 0.3381 - root_mean_squared_error: 0.5815 - val_loss: 1.8055 - val_root_mean_squared_error: 1.3437 - 10s/epoch - 8ms/step
# Epoch 106/2000
# 1221/1221 - 9s - loss: 0.3379 - root_mean_squared_error: 0.5813 - val_loss: 1.8058 - val_root_mean_squared_error: 1.3438 - 9s/epoch - 7ms/step
# Epoch 107/2000
# 1221/1221 - 10s - loss: 0.3376 - root_mean_squared_error: 0.5811 - val_loss: 1.8062 - val_root_mean_squared_error: 1.3440 - 10s/epoch - 8ms/step
# Epoch 108/2000
# 1221/1221 - 10s - loss: 0.3374 - root_mean_squared_error: 0.5809 - val_loss: 1.8066 - val_root_mean_squared_error: 1.3441 - 10s/epoch - 8ms/step
# Epoch 109/2000
# 1221/1221 - 10s - loss: 0.3372 - root_mean_squared_error: 0.5807 - val_loss: 1.8068 - val_root_mean_squared_error: 1.3442 - 10s/epoch - 8ms/step
# Epoch 110/2000
# 1221/1221 - 9s - loss: 0.3369 - root_mean_squared_error: 0.5805 - val_loss: 1.8072 - val_root_mean_squared_error: 1.3443 - 9s/epoch - 7ms/step
# Epoch 111/2000
# 1221/1221 - 10s - loss: 0.3367 - root_mean_squared_error: 0.5803 - val_loss: 1.8075 - val_root_mean_squared_error: 1.3444 - 10s/epoch - 9ms/step
# Epoch 112/2000
# 1221/1221 - 10s - loss: 0.3365 - root_mean_squared_error: 0.5801 - val_loss: 1.8077 - val_root_mean_squared_error: 1.3445 - 10s/epoch - 8ms/step
# Epoch 113/2000
# 1221/1221 - 9s - loss: 0.3363 - root_mean_squared_error: 0.5799 - val_loss: 1.8080 - val_root_mean_squared_error: 1.3446 - 9s/epoch - 8ms/step
# Epoch 114/2000
# 1221/1221 - 9s - loss: 0.3360 - root_mean_squared_error: 0.5797 - val_loss: 1.8083 - val_root_mean_squared_error: 1.3447 - 9s/epoch - 7ms/step
# Epoch 115/2000
# 1221/1221 - 10s - loss: 0.3358 - root_mean_squared_error: 0.5795 - val_loss: 1.8087 - val_root_mean_squared_error: 1.3449 - 10s/epoch - 8ms/step
# Epoch 116/2000
# 1221/1221 - 9s - loss: 0.3356 - root_mean_squared_error: 0.5793 - val_loss: 1.8091 - val_root_mean_squared_error: 1.3450 - 9s/epoch - 7ms/step
# Epoch 117/2000
# 1221/1221 - 9s - loss: 0.3354 - root_mean_squared_error: 0.5791 - val_loss: 1.8094 - val_root_mean_squared_error: 1.3451 - 9s/epoch - 8ms/step
# Epoch 118/2000
# 1221/1221 - 9s - loss: 0.3351 - root_mean_squared_error: 0.5789 - val_loss: 1.8097 - val_root_mean_squared_error: 1.3452 - 9s/epoch - 8ms/step
# Epoch 119/2000
# 1221/1221 - 9s - loss: 0.3349 - root_mean_squared_error: 0.5787 - val_loss: 1.8100 - val_root_mean_squared_error: 1.3453 - 9s/epoch - 8ms/step
# Epoch 120/2000
# 1221/1221 - 11s - loss: 0.3347 - root_mean_squared_error: 0.5785 - val_loss: 1.8102 - val_root_mean_squared_error: 1.3455 - 11s/epoch - 9ms/step
# Epoch 121/2000
# 1221/1221 - 10s - loss: 0.3345 - root_mean_squared_error: 0.5783 - val_loss: 1.8104 - val_root_mean_squared_error: 1.3455 - 10s/epoch - 8ms/step
# Epoch 122/2000
# 1221/1221 - 10s - loss: 0.3342 - root_mean_squared_error: 0.5781 - val_loss: 1.8107 - val_root_mean_squared_error: 1.3456 - 10s/epoch - 8ms/step
# Epoch 123/2000
# 1221/1221 - 8s - loss: 0.3340 - root_mean_squared_error: 0.5779 - val_loss: 1.8110 - val_root_mean_squared_error: 1.3457 - 8s/epoch - 7ms/step
# Epoch 124/2000
# 1221/1221 - 10s - loss: 0.3337 - root_mean_squared_error: 0.5777 - val_loss: 1.8113 - val_root_mean_squared_error: 1.3459 - 10s/epoch - 8ms/step
# Epoch 125/2000
# 1221/1221 - 10s - loss: 0.3335 - root_mean_squared_error: 0.5775 - val_loss: 1.8117 - val_root_mean_squared_error: 1.3460 - 10s/epoch - 8ms/step
# Epoch 126/2000
# 1221/1221 - 9s - loss: 0.3333 - root_mean_squared_error: 0.5773 - val_loss: 1.8120 - val_root_mean_squared_error: 1.3461 - 9s/epoch - 8ms/step
# Epoch 127/2000
# 1221/1221 - 10s - loss: 0.3330 - root_mean_squared_error: 0.5771 - val_loss: 1.8124 - val_root_mean_squared_error: 1.3462 - 10s/epoch - 8ms/step
# Epoch 128/2000
# 1221/1221 - 9s - loss: 0.3328 - root_mean_squared_error: 0.5769 - val_loss: 1.8125 - val_root_mean_squared_error: 1.3463 - 9s/epoch - 7ms/step
# Epoch 129/2000
# 1221/1221 - 9s - loss: 0.3325 - root_mean_squared_error: 0.5767 - val_loss: 1.8127 - val_root_mean_squared_error: 1.3464 - 9s/epoch - 8ms/step
# Epoch 130/2000
# 1221/1221 - 10s - loss: 0.3323 - root_mean_squared_error: 0.5765 - val_loss: 1.8129 - val_root_mean_squared_error: 1.3464 - 10s/epoch - 8ms/step
# Epoch 131/2000
# 1221/1221 - 10s - loss: 0.3320 - root_mean_squared_error: 0.5762 - val_loss: 1.8130 - val_root_mean_squared_error: 1.3465 - 10s/epoch - 8ms/step
# Epoch 132/2000
# 1221/1221 - 10s - loss: 0.3318 - root_mean_squared_error: 0.5760 - val_loss: 1.8131 - val_root_mean_squared_error: 1.3465 - 10s/epoch - 8ms/step
# Epoch 133/2000
# 1221/1221 - 9s - loss: 0.3315 - root_mean_squared_error: 0.5758 - val_loss: 1.8132 - val_root_mean_squared_error: 1.3466 - 9s/epoch - 7ms/step
# Epoch 134/2000
# 1221/1221 - 10s - loss: 0.3313 - root_mean_squared_error: 0.5756 - val_loss: 1.8135 - val_root_mean_squared_error: 1.3467 - 10s/epoch - 8ms/step
# Epoch 135/2000
# 1221/1221 - 9s - loss: 0.3310 - root_mean_squared_error: 0.5753 - val_loss: 1.8139 - val_root_mean_squared_error: 1.3468 - 9s/epoch - 8ms/step
# Epoch 136/2000
# 1221/1221 - 10s - loss: 0.3307 - root_mean_squared_error: 0.5751 - val_loss: 1.8142 - val_root_mean_squared_error: 1.3469 - 10s/epoch - 8ms/step
# Epoch 137/2000
# 1221/1221 - 10s - loss: 0.3305 - root_mean_squared_error: 0.5749 - val_loss: 1.8144 - val_root_mean_squared_error: 1.3470 - 10s/epoch - 8ms/step
# Epoch 138/2000
# 1221/1221 - 9s - loss: 0.3302 - root_mean_squared_error: 0.5746 - val_loss: 1.8146 - val_root_mean_squared_error: 1.3471 - 9s/epoch - 7ms/step
# Epoch 139/2000
# 1221/1221 - 9s - loss: 0.3299 - root_mean_squared_error: 0.5744 - val_loss: 1.8147 - val_root_mean_squared_error: 1.3471 - 9s/epoch - 8ms/step
# Epoch 140/2000
# 1221/1221 - 11s - loss: 0.3296 - root_mean_squared_error: 0.5741 - val_loss: 1.8149 - val_root_mean_squared_error: 1.3472 - 11s/epoch - 9ms/step
# Epoch 141/2000
# 1221/1221 - 9s - loss: 0.3293 - root_mean_squared_error: 0.5739 - val_loss: 1.8151 - val_root_mean_squared_error: 1.3472 - 9s/epoch - 7ms/step
# Epoch 142/2000
# 1221/1221 - 10s - loss: 0.3290 - root_mean_squared_error: 0.5736 - val_loss: 1.8153 - val_root_mean_squared_error: 1.3473 - 10s/epoch - 9ms/step
# Epoch 143/2000
# 1221/1221 - 10s - loss: 0.3287 - root_mean_squared_error: 0.5733 - val_loss: 1.8155 - val_root_mean_squared_error: 1.3474 - 10s/epoch - 8ms/step
# Epoch 144/2000
# 1221/1221 - 9s - loss: 0.3283 - root_mean_squared_error: 0.5730 - val_loss: 1.8159 - val_root_mean_squared_error: 1.3475 - 9s/epoch - 8ms/step
# Epoch 145/2000
# 1221/1221 - 11s - loss: 0.3280 - root_mean_squared_error: 0.5727 - val_loss: 1.8162 - val_root_mean_squared_error: 1.3477 - 11s/epoch - 9ms/step
# Epoch 146/2000
# 1221/1221 - 9s - loss: 0.3276 - root_mean_squared_error: 0.5724 - val_loss: 1.8167 - val_root_mean_squared_error: 1.3478 - 9s/epoch - 7ms/step
# Epoch 147/2000
# 1221/1221 - 10s - loss: 0.3273 - root_mean_squared_error: 0.5721 - val_loss: 1.8170 - val_root_mean_squared_error: 1.3480 - 10s/epoch - 8ms/step
# Epoch 148/2000
# 1221/1221 - 10s - loss: 0.3269 - root_mean_squared_error: 0.5718 - val_loss: 1.8173 - val_root_mean_squared_error: 1.3481 - 10s/epoch - 8ms/step
# Epoch 149/2000
# 1221/1221 - 10s - loss: 0.3265 - root_mean_squared_error: 0.5714 - val_loss: 1.8176 - val_root_mean_squared_error: 1.3482 - 10s/epoch - 8ms/step
# Epoch 150/2000
# 1221/1221 - 9s - loss: 0.3261 - root_mean_squared_error: 0.5711 - val_loss: 1.8178 - val_root_mean_squared_error: 1.3483 - 9s/epoch - 8ms/step
# Epoch 151/2000
# 1221/1221 - 9s - loss: 0.3257 - root_mean_squared_error: 0.5707 - val_loss: 1.8181 - val_root_mean_squared_error: 1.3484 - 9s/epoch - 8ms/step
# Epoch 152/2000
# 1221/1221 - 9s - loss: 0.3253 - root_mean_squared_error: 0.5704 - val_loss: 1.8185 - val_root_mean_squared_error: 1.3485 - 9s/epoch - 7ms/step
# Epoch 153/2000
# 1221/1221 - 9s - loss: 0.3248 - root_mean_squared_error: 0.5699 - val_loss: 1.8190 - val_root_mean_squared_error: 1.3487 - 9s/epoch - 7ms/step
# Epoch 154/2000
# 1221/1221 - 9s - loss: 0.3243 - root_mean_squared_error: 0.5695 - val_loss: 1.8196 - val_root_mean_squared_error: 1.3489 - 9s/epoch - 7ms/step
# Epoch 155/2000
# 1221/1221 - 9s - loss: 0.3237 - root_mean_squared_error: 0.5690 - val_loss: 1.8204 - val_root_mean_squared_error: 1.3492 - 9s/epoch - 7ms/step
# Epoch 156/2000
# 1221/1221 - 10s - loss: 0.3231 - root_mean_squared_error: 0.5684 - val_loss: 1.8212 - val_root_mean_squared_error: 1.3495 - 10s/epoch - 8ms/step
# Epoch 157/2000
# 1221/1221 - 9s - loss: 0.3224 - root_mean_squared_error: 0.5678 - val_loss: 1.8223 - val_root_mean_squared_error: 1.3499 - 9s/epoch - 8ms/step
# Epoch 158/2000
# 1221/1221 - 9s - loss: 0.3216 - root_mean_squared_error: 0.5671 - val_loss: 1.8237 - val_root_mean_squared_error: 1.3505 - 9s/epoch - 7ms/step
# Epoch 159/2000
# 1221/1221 - 10s - loss: 0.3207 - root_mean_squared_error: 0.5663 - val_loss: 1.8256 - val_root_mean_squared_error: 1.3512 - 10s/epoch - 8ms/step
# Epoch 160/2000
# 1221/1221 - 10s - loss: 0.3199 - root_mean_squared_error: 0.5656 - val_loss: 1.8274 - val_root_mean_squared_error: 1.3518 - 10s/epoch - 8ms/step
# INFO:tensorflow:Assets written to: ram://277752f2-a5ec-409f-b96e-dd71f06fbb33/assets
# INFO:tensorflow:Assets written to: ram://277752f2-a5ec-409f-b96e-dd71f06fbb33/assets
# WARNING:absl:<keras.layers.recurrent.LSTM object at 0x0000020D4B07D550> has the same name 'LSTM' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTM'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000020D4B07D580> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# One step ahead predict for standard data
df_test = li_train_cycles[2].copy()
TIMESTEPS = 10

iloc_cntr_on = (df_test['contactor_state'].values != constants.CONTACTOR_OFF).argmax()   # find iloc of first occurance when of contactor_on
df_test = df_test.iloc[iloc_cntr_on:]            # Extract all rows starting from contactor on
# print(len(df_test))

df_test = df_test[['V', 'current', 'Temp']]   # only necessary columns

# statndard
df_test['V_standard'] = StandardScaler().fit_transform(df_test[['V']])
df_test['cur_standard'] = StandardScaler().fit_transform(df_test[['current']])

X, y = df_to_supervised_univariate(df_test['cur_standard'], df_test['V_standard'], TIMESTEPS)     # standard

# %%
# 1 step prediction
iteration_no = ''
# FORECAST_SECONDS = len(df_test)
FORECAST_SECONDS = y.shape[0]

model_path = os.path.join(cwd, 'generalized', 'stationary', 'model_standard_' + str(iteration_no) + '.h5')

from keras.models import load_model

model = load_model(model_path)

print(X.shape, y.shape)

lstm_gen_predictions = model.predict(X)
lstm_gen_predictions = np.squeeze(lstm_gen_predictions)

print(lstm_gen_predictions.shape)
# Out:
# (1417, 10, 1) (1417,)
# (1417,)

# %%
# %matplotlib notebook

x_axis = np.arange(lstm_gen_predictions.shape[0])
y = y[:FORECAST_SECONDS]

# This displays result  for concat standardized 1 step ahead pred plot wehre training was not successful

save_path = os.path.join(cwd, 'generalized', 'stationary', 'model_standard_' + str(iteration_no) + '.pdf')
custom_plot.plot_multi_line(("LSTM one step ahead prediction", save_path, "Voltage (V)"), (x_axis, constants.x_label_elapsedtime), (y, "Actual"), (lstm_gen_predictions, "Prediction"))
# Out:
# <img src="data:image/png;base64,..." width="1426.3636054480378">
# WARNING:matplotlib.font_manager:findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### normalization and standardization result for single time series: validation loss increases with time.
# Hint: plot cwd\generalized\stationary\history_standard_.pkl

# %% [markdown]
# ### Smoothing: make polynomial

# %%
# %matplotlib notebook

from statsmodels.tsa.stattools import adfuller
import numpy.polynomial.polynomial as poly

from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline


df = li_train_cycles[2].copy()
TIMESTEPS = 10

df = df[['V', 'current', 'Temp', 'elapsed_sec']]   # only necessary columns


plt.scatter(df['elapsed_sec'], df['current'])

#fit polynomial models up to degree 5
# model1 = np.poly1d(np.polyfit(df['elapsed_sec'], df['current'], 1))
# model2 = np.poly1d(np.polyfit(df['elapsed_sec'], df['current'], 2))
# model3 = np.poly1d(np.polyfit(df['elapsed_sec'], df['current'], 3))
# model4 = np.poly1d(np.polyfit(df['elapsed_sec'], df['current'], 4))
# model5 = np.poly1d(np.polyfit(df.x, df.y, 5))
model10 = np.poly1d(np.polyfit(df['elapsed_sec'], df['current'], 10))

#create scatterplot
polyline = np.linspace(0, len(df), len(df))       # (low, high, #total_elements)
# plt.scatter(df.x, df.y)

#add fitted polynomial lines to scatterplot 
# plt.plot(polyline, model1(polyline), color='green')
# plt.plot(polyline, model2(polyline), color='red')
# plt.plot(polyline, model3(polyline), color='purple')
# plt.plot(polyline, model4(polyline), color='blue')
plt.plot(polyline, model10(polyline), color='blue')
# plt.plot(polyline, model5(polyline), color='orange')
plt.show()


# coefs = poly.polyfit(x, y, 2)
# ffit = poly.polyval(x_new, coefs)
# plt.plot(x_new, ffit)


# statndard
# df_test['V_standard'] = StandardScaler().fit_transform(df_test[['V']])
# df_test['cur_standard'] = StandardScaler().fit_transform(df_test[['current']])

# df_transform = df.copy()

# # transform to stationary
# df1 = df_transform['current'].apply(np.log)
# # df1 = np.log(df_transform['current']) # equivalent
# # plot_chart(df1, 'Current (Log)') # equivalent
# df1.plot(kind = 'scatter', x = 'Time', y = 'Current')
# plt.show()


# check stationarity
# result=adfuller (df_diff['current'])
# print('Test Statistic: %f' %result[0])
# print('p-value: %f' %result[1])
# print('Critical values:')
# for key, value in result[4].items ():
#      print('\t%s: %.3f' %(key, value))

# X, y = df_to_supervised_univariate(df_test['cur_standard'], df_test['V_standard'], TIMESTEPS)     # standard
# Out:
# <img src="data:image/png;base64,..." width="1393.6363334301095">

# %% [markdown]
# ### detrend TS

# %%
from scipy import signal

df = li_train_cycles[2].copy()
TIMESTEPS = 10

df = df[['V', 'current', 'Temp', 'elapsed_sec']]   # only necessary columns

detrended = signal.detrend(df['current'])

detrended_df = pd.DataFrame(detrended)
detrended_df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <AxesSubplot:>

# %% [markdown]
# ### exponential smoothing

# %%
# %matplotlib notebook

# simple 
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

import matplotlib.pyplot as plt

df = li_train_cycles[2].copy()
TIMESTEPS = 10

df = df[['V', 'current', 'Temp', 'elapsed_sec']]   # only necessary columns

fit1 = SimpleExpSmoothing(df['current']).fit(smoothing_level=0.1, optimized=False)   # smoothing level higher = closer to original
# fit2 = Holt(df['current'], initialization_method="estimated").fit()

df['current_smooth_exp'] = fit1.fittedvalues 

plt.plot(df['current'])
plt.plot(fit1.fittedvalues)
print(type(fit1.fittedvalues))
# plt.plot(fit2.fittedvalues)
plt.show()
# Out:
# C:\Users\s.kaiser\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <class 'pandas.core.series.Series'>
